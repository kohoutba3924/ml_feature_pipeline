# %%
# Imports and file path
import pandas as pd
from pathlib import Path

# Path to your Parquet file
parquet_path = Path("../data/external/lcdv2_stations.parquet")

# %%
# Load the Parquet file
df = pd.read_parquet(parquet_path)
df.head()
# Out:
#       station                                            name  latitude  \
# 0  WBAN:00132                WAUTOMA MUNICIPAL AIRPORT, WI US    44.033
# 1  WBAN:00183            PLATTEVILLE MUNICIPAL AIRPORT, WI US    42.683
# 2  WBAN:00185                SHAWANO MUNICIPAL AIRPORT, WI US    44.783
# 3  WBAN:00236  MIDDLETON MUNICIPAL MOREY FIELD AIRPORT, WI US    43.117
# 4  WBAN:00241                VIROQUA MUNICIPAL AIRPORT, WI US    43.579
#
#    longitude  elevation  data_coverage    min_date    max_date
# 0    -89.300      262.1            1.0  2014-07-31  2025-08-25
# 1    -90.450      312.1            1.0  2009-01-01  2025-08-25
# 2    -88.550      248.1            1.0  2009-02-01  2025-08-25
# 3    -89.533      283.2            1.0  2014-07-31  2025-08-25
# 4    -90.913      394.1            1.0  2014-07-31  2025-08-25

# %%
# Schema and metadata
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   station        64 non-null     str
#  1   name           64 non-null     str
#  2   latitude       64 non-null     float64
#  3   longitude      64 non-null     float64
#  4   elevation      64 non-null     float64
#  5   data_coverage  64 non-null     float64
#  6   min_date       64 non-null     str
#  7   max_date       64 non-null     str
# dtypes: float64(4), str(4)
# memory usage: 8.1 KB

# %%
# Quick sampling
df.sample(10)
# Out:
#        station                                            name  latitude  \
# 16  WBAN:04864               ANTIGO LANGLADE CO AIRPORT, WI US  45.15417
# 21  WBAN:04891                MERRILL MUNICIPAL AIRPORT, WI US  45.19917
# 49  WBAN:54913                PHILLIPS PRICE CO AIRPORT, WI US  45.70889
# 39  WBAN:54833          BARABOO WISCONSIN DELLS AIRPORT, WI US  43.52194
# 38  WBAN:54832           CLINTONVILLE MUNICIPAL AIRPORT, WI US  44.61389
# 12  WBAN:04826         WISCONSIN RAPIDS ALEXANDER FIELD, WI US  44.35904
# 10  WBAN:04824  STURGEON BAY DOOR CO CHERRYLAND AIRPORT, WI US  44.85000
# 61  WBAN:94973                HAYWARD MUNICIPAL AIRPORT, WI US  46.03028
# 15  WBAN:04845                 KENOSHA REGIONAL AIRPORT, WI US  42.59529
# 50  WBAN:54928                LADYSMITH RUSK CO AIRPORT, WI US  45.49694
#
#     longitude  elevation  data_coverage    min_date    max_date
# 16  -89.11056      463.9            1.0  2005-01-01  2025-08-25
# 21  -89.71139      401.4            1.0  2005-01-01  2025-08-25
# 49  -90.40222      456.3            1.0  2005-05-05  2025-08-25
# 39  -89.77361      297.5            1.0  2005-04-07  2025-08-25
# 38  -88.73139      250.5            1.0  2005-04-07  2025-08-25
# 12  -89.83695      309.4            1.0  2005-01-01  2025-08-27
# 10  -87.41667      220.7            1.0  2005-01-01  2025-08-25
# 61  -91.44263      368.9            1.0  2005-01-01  2025-08-27
# 15  -87.93832      223.5            1.0  2005-01-01  2025-08-25
# 50  -91.00056      377.3            1.0  2006-11-27  2025-08-25

# %%
# Basic profiling
df.describe(include="all")
# Out:
#            station                              name   latitude  longitude  \
# count           64                                64  64.000000  64.000000
# unique          64                                64        NaN        NaN
# top     WBAN:00132  WAUTOMA MUNICIPAL AIRPORT, WI US        NaN        NaN
# freq             1                                 1        NaN        NaN
# mean           NaN                               NaN  44.354024 -89.788837
# std            NaN                               NaN   1.117705   1.385103
# min            NaN                               NaN  42.595290 -92.690000
# 25%            NaN                               NaN  43.365268 -90.763747
# 50%            NaN                               NaN  44.346185 -89.689030
# 75%            NaN                               NaN  45.165420 -88.666400
# max            NaN                               NaN  46.689440 -87.416670
#
#          elevation  data_coverage    min_date    max_date
# count    64.000000      64.000000          64          64
# unique         NaN            NaN          23           5
# top            NaN            NaN  2005-01-01  2025-08-25
# freq           NaN            NaN          28          45
# mean    304.009375       0.992812         NaN         NaN
# std      91.174383       0.042779         NaN         NaN
# min     184.400000       0.690000         NaN         NaN
# 25%     238.900000       1.000000         NaN         NaN
# 50%     276.450000       1.000000         NaN         NaN
# 75%     366.725000       1.000000         NaN         NaN
# max     519.400000       1.000000         NaN         NaN

# %%
# Check for missing values
df.isna().sum()
# Out:
# station          0
# name             0
# latitude         0
# longitude        0
# elevation        0
# data_coverage    0
# min_date         0
# max_date         0
# dtype: int64
